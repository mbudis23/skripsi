# %%
import scipy.io
import numpy as np
import pandas as pd
from pathlib import Path
import gymnasium as gym
from gymnasium import spaces
from sb3_contrib import RecurrentPPO
from stable_baselines3 import PPO
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from stable_baselines3.common.env_checker import check_env
import pandas as pd
from pathlib import Path
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from stable_baselines3 import PPO
from stable_baselines3 import DDPG # Ganti PPO ke DDPG
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from stable_baselines3 import PPO
from stable_baselines3 import DDPG, TD3
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from sklearn.metrics import mean_squared_error, r2_score
from sb3_contrib import TRPO
print("INFO: Import Library")
# Out:
# INFO: Import Library

# %% [markdown]
# # Load Dataset

# %%
# Function to load mat file
def load_mat_file(file_path):
    path =Path(file_path)
    try:
        mat = scipy.io.loadmat(path)
        if 'meas' not in mat:
            print(f"ERROR: Key 'meas' is not found in {path.name}")
            return None
        
        data_struct = mat["meas"][0,0]
        names = data_struct.dtype.names
        raw_data = {}
        for name in names:
            content = data_struct[name].flatten()
            
            if len(content) > 0 and isinstance(content[0], np.ndarray):
                raw_data[name] = content[0].flatten()
            else:
                raw_data[name] = content
            
        lengths = [len(v) for v in raw_data.values() if isinstance(v, (np.ndarray, list))]
        max_len = max(lengths) if lengths else 1

        final_data = {}
        for name, values in raw_data.items():
            curr_len = len(values) if isinstance(values, (np.ndarray, list)) else 1
            
            if curr_len != max_len:
                single_val = values[0] if curr_len > 0 else np.nan
                if hasattr(single_val, 'decode'):
                    single_val = single_val.decode('utf-8')
                final_data[name] = [single_val] * max_len
            else:
                if isinstance(values, np.ndarray) and values.dtype.kind in ['S', 'V']:
                    final_data[name] = [v.decode('utf-8') if hasattr(v, 'decode') else v for v in values]
                else:
                    final_data[name] = values

        df = pd.DataFrame(final_data)
        return df


    except Exception as e:
        print(f"ERROR: Failed to load {path.name}. {e}")

# %%
# Load dataset into df_master
base_path = Path('datasets/1-Open Data')

all_dfs = []

for file_path in base_path.rglob('*.mat'):
    try:
        print(f'INFO: System is processing to load {file_path}')
        df_temp = load_mat_file(str(file_path))
        
        df_temp['Session_ID'] = file_path 
        df_temp['SOC_lag_1'] = df_temp['SOC'].shift(1)
        df_temp = df_temp.dropna(subset=['SOC_lag_1'])
        
        all_dfs.append(df_temp)
        print(f"INFO: Success to load {file_path}")
        
    except Exception as e:
        print(f"ERROR: Failed to load {file_path}: {e}")

df_master = pd.concat(all_dfs, ignore_index=True)
df_master = df_master.drop(columns=[
    'TimeStamp', 
    'Time', 
    'Battery_Temp_degC', 
    'Ambient_Temp_degC', 
    'Cycle_Label', 
    'Test_Cell', 
    # 'Session_ID'
    ])
df_master.sample(5)
# Out:
# INFO: System is processing to load datasets/1-Open Data/m1000/40C/Drive Cycles/20_REORDERED6_05-17-21_13.21 Tesla_40C_DriveCycles_Ch4.mat
# INFO: Success to load datasets/1-Open Data/m1000/40C/Drive Cycles/20_REORDERED6_05-17-21_13.21 Tesla_40C_DriveCycles_Ch4.mat
# INFO: System is processing to load datasets/1-Open Data/m1000/40C/Drive Cycles
Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/29_CC_CV_charge_06-17-21_08.46 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/10_REORDERED1_06-06-21_12.48 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/10_REORDERED1_06-06-21_12.48 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/13_CC_CV_charge_06-07-21_17.46 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/13_CC_CV_charge_06-07-21_17.46 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/17_CC_CV_charge_06-09-21_04.02 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/17_CC_CV_charge_06-09-21_04.02 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/20_REORDERED6_06-15-21_05.30 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/20_REORDERED6_06-15-21_05.30 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/21_CC_CV_charge_06-15-21_14.46 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/21_CC_CV_charge_06-15-21_14.46 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/26_HWCUST1_06-16-21_22.18 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/26_HWCUST1_06-16-21_22.18 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Drive Cycles/14_REORDERED3_06-08-21_01.40 Tesla_25C_DriveCycles_Ch1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Drive Cycles/14_REORDERED3_06-08-21_01.40 Tesla_25C_DriveCycles_Ch1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/2_40C_Discharge_05-25-21_18.32 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/2_40C_Discharge_05-25-21_18.32 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/4_C_3_Discharge_05-26-21_19.09 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/4_C_3_Discharge_05-26-21_19.09 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/7_CC_CV_charge_05-28-21_05.11 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/7_CC_CV_charge_05-28-21_05.11 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/10_CC_CV_charge_05-30-21_03.58 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/10_CC_CV_charge_05-30-21_03.58 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/3_CC_CV_charge_05-26-21_15.43 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/3_CC_CV_charge_05-26-21_15.43 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/9_0.5C_Discharge_05-30-21_02.02 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/9_0.5C_Discharge_05-30-21_02.02 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/5_CC_CV_charge_05-26-21_22.08 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/5_CC_CV_charge_05-26-21_22.08 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/6_HPPC_05-27-21_01.23 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/6_HPPC_05-27-21_01.23 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: System is processing to load datasets/1-Open Data/m80/25C/Characterization Tests/1_Other_05-25-21_17.45 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
# INFO: Success to load datasets/1-Open Data/m80/25C/Characterization Tests/1_Other_05-25-21_17.45 Tesla_25C_Cher_V5_Channel_1_Wb_1.mat
#            Voltage   Current        Ah       SOC     Power         Wh  \
# 21864919  4.200000  0.057708  0.027634  0.993762  0.242374  -0.318265
# 9703282   3.570100 -0.026209  3.115900  0.322776 -0.093570  11.788500
# 7233157   3.356290  0.000000  3.626950  0.154788  0.000000  12.743610
# 6624818   4.163314  0.000000  0.000000  1.000000  0.000000  -2.322890
# 18220725  4.200100  0.149839  0.021900  0.995317  0.629340 -16.099000
#
#                                                  Session_ID  SOC_lag_1
# 21864919  datasets/1-Open Data/m80/10C/Characterization ...   0.993758
# 9703282   datasets/1-Open Data/m448-N/40C/Drive Cycles/1...   0.322776
# 7233157   datasets/1-Open Data/m1000/0C/Drive Cycles/29_...   0.154788
# 6624818   datasets/1-Open Data/m1000/0C/Characterization...   1.000000
# 18220725  datasets/1-Open Data/m80/40C/Characterization ...   0.995302

# %% [markdown]
# # Reinforcement Learning

# %%
features = ['Voltage', 'Current', 'Ah', 'Power', 'Wh', 'SOC_lag_1']

scaler = MinMaxScaler()
df_master[features] = scaler.fit_transform(df_master[features])

sessions = df_master['Session_ID'].unique()
train_sessions = sessions[:int(0.8 * len(sessions))]
test_sessions = sessions[int(0.8 * len(sessions)):]

df_train = df_master[df_master['Session_ID'].isin(train_sessions)].reset_index(drop=True)
df_test = df_master[df_master['Session_ID'].isin(test_sessions)].reset_index(drop=True)

# %%
class BatteryEnv(gym.Env):
    def __init__(self, df):
        super(BatteryEnv, self).__init__()
        self.df = df
        self.sessions = df['Session_ID'].unique()
        
        self.action_space = spaces.Box(low=0.0, high=1.0, shape=(1,), dtype=np.float32)
        
        self.observation_space = spaces.Box(
            low=-np.inf, 
            high=np.inf, 
            shape=(len(features),), 
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        session_id = np.random.choice(self.sessions)
        self.episode_data = self.df[self.df['Session_ID'] == session_id].reset_index(drop=True)
        self.current_step = 0
        return self._get_obs(), {}

    def _get_obs(self):
        row = self.episode_data.iloc[self.current_step]
        return np.array(row[features].values, dtype=np.float32)

    def step(self, action):
        target_soc = self.episode_data.iloc[self.current_step]['SOC']
        
        reward = -abs(action[0] - target_soc)
        
        self.current_step += 1
        terminated = self.current_step >= len(self.episode_data) - 1
        
        obs = self._get_obs() if not terminated else np.zeros(self.observation_space.shape, dtype=np.float32)
        
        return obs, reward, terminated, False, {"target": target_soc}

# %%
env = BatteryEnv(df_train)

n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# %%
def evaluate_model(model, df_eval):
    all_sessions = df_eval['Session_ID'].unique()
    random_idx = np.random.randint(0, len(all_sessions))
    
    test_session_id = df_eval['Session_ID'].unique()[random_idx]
    data_test = df_eval[df_eval['Session_ID'] == test_session_id].reset_index(drop=True)
    
    predictions = []
    targets = []
    
    obs = np.array(data_test.iloc[0][features].values, dtype=np.float32)
    
    print(f"INFO: Evaluating Session: {test_session_id} ---")
    
    for i in range(len(data_test)):
        action, _states = model.predict(obs, deterministic=True)
        predictions.append(action[0])
        targets.append(data_test.iloc[i]['SOC'])
        
        if i + 1 < len(data_test):
            obs = np.array(data_test.iloc[i+1][features].values, dtype=np.float32)

    targets = np.array(targets)
    predictions = np.array(predictions)

    mae = np.mean(np.abs(targets - predictions))
    rmse = np.sqrt(mean_squared_error(targets, predictions))
    r2 = r2_score(targets, predictions)
    
    mape = np.mean(np.abs((targets - predictions) / (targets + 1e-10))) * 100

    print(f"MAE   : {mae:.5f}")
    print(f"RMSE  : {rmse:.5f}")
    print(f"MAPE  : {mape:.2f}%")
    print(f"R2    : {r2:.5f}")

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1]})

    ax1.plot(targets, label='Actual SOC', color='#1f77b4', linewidth=2)
    ax1.plot(predictions, label='Predicted SOC (RL)', color='#d62728', linestyle='--')
    ax1.set_title(f'SOC Prediction Analysis - {test_session_id}')
    ax1.set_ylabel('State of Charge')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    error = predictions - targets
    ax2.fill_between(range(len(error)), error, color='gray', alpha=0.5, label='Error (Pred - Target)')
    ax2.axhline(y=0, color='black', linestyle='-', linewidth=0.8)
    ax2.set_xlabel('Time Step')
    ax2.set_ylabel('Error')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    return {"mae": mae, "rmse": rmse, "mape": mape, "r2": r2}

# %% [markdown]
# # Deep Deterministic Policy Gradient

# %%
DDPG_model = DDPG(
    "MlpPolicy", 
    env, 
    action_noise=action_noise,
    verbose=1, 
    learning_rate=0.001, # DDPG biasanya butuh LR yang disesuaikan
    buffer_size=100000,   # DDPG menggunakan Replay Buffer
    batch_size=64,
    tau=0.005,            # Soft update coefficient
    gamma=0.99
)

print("INFO:Model Learning Start")
DDPG_model.learn(total_timesteps=100000)
DDPG_model.save("ddpg_soc_battery")
print("INFO:Model Learning Finished")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# INFO:Model Learning Start
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.2e+04  |
# |    ep_rew_mean     | -640     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 190      |
# |    time_elapsed    | 461      |
# |    total_timesteps | 88099    |
# | train/             |          |
# |    actor_loss      | 0.158    |
# |    critic_loss     | 1.22e-05 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87998    |
# ---------------------------------
# INFO:Model Learning Finished

# %%
evaluate_model(DDPG_model, df_test)
# Out:
# INFO: Evaluating Session: datasets/1-Open Data/m80/-10C/Characterization Tests/7_CC_CV_charge_10-27-21_05.28 Tesla_Char_-10C_V3_Channel_1_Wb_1.mat ---
# MAE   : 0.00606
# RMSE  : 0.00822
# MAPE  : 2.75%
# R2    : 0.99958
# {'mae': np.float64(0.006062747666994486),
#  'rmse': np.float64(0.008217994791713685),
#  'mape': np.float64(2.748733892499348),
#  'r2': 0.9995762503042391}

# %% [markdown]
# # Twin Delayed Deep Deterministic Policy Gradient

# %%
TD3_model = TD3(
    "MlpPolicy", 
    env, 
    action_noise=action_noise,
    verbose=1, 
    learning_rate=0.001,
    buffer_size=100000,
    batch_size=100,       # TD3 biasanya bekerja baik dengan batch size sedikit lebih besar
    tau=0.005,
    gamma=0.99,
    policy_delay=2,       # Parameter khas TD3: Update policy setiap 2 kali update critic
    target_policy_noise=0.2, # Noise tambahan untuk target smoothing
    target_noise_clip=0.5
)

print("INFO: Model learn starting...")
TD3_model.learn(total_timesteps=100000)
TD3_model.save("td3_soc_battery")
print("INFO: Model learn finished")
evaluate_model(TD3_model, df_test)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# INFO: Model learn starting...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+04 |
# |    ep_rew_mean     | -447     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 166      |
# |    time_elapsed    | 307      |
# |    total_timesteps | 51272    |
# | train/             |          |
# |    actor_loss      | 3.51     |
# |    critic_loss     | 0.00771  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51171    |
# ---------------------------------
# INFO: Model learn finished
# INFO: Evaluating Session: datasets/1-Open Data/m80/-10C/Drive Cycles/23_CC_CV_charge_11-12-21_23.15 Tesla_n10C_DriveCycles_Ch1.mat ---
# MAE   : 0.02120
# RMSE  : 0.02587
# MAPE  : 7.44%
# R2    : 0.99470
# {'mae': np.float64(0.02119608550328733),
#  'rmse': np.float64(0.025868988750641288),
#  'mape': np.float64(7.435642817281645),
#  'r2': 0.994695116746772}

# %% [markdown]
# # Soft Actor Critic

# %%
from stable_baselines3 import SAC

# Catatan: SAC biasanya tidak membutuhkan 'action_noise' eksternal karena memiliki 
# mekanisme entropy tuning otomatis untuk eksplorasi.

SAC_model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=0.001,
    buffer_size=100000,
    batch_size=100,       
    tau=0.005,
    gamma=0.99,
    # Parameter khas SAC:
    ent_coef="auto",      # Mengoptimalkan entropi secara otomatis
    train_freq=1,         # Update setiap langkah
    gradient_steps=1,     # Berapa kali gradient update per step
    use_sde=False,        # State Dependent Exploration (bisa True untuk kontrol robotik halus)
)

print("INFO: SAC Model learn starting...")
SAC_model.learn(total_timesteps=100000)
SAC_model.save("sac_soc_battery")
print("INFO: SAC Model learn finished")

evaluate_model(SAC_model, df_test)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# INFO: SAC Model learn starting...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.55e+04  |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 138       |
# |    time_elapsed    | 450       |
# |    total_timesteps | 62148     |
# | train/             |           |
# |    actor_loss      | 12.3      |
# |    critic_loss     | 0.000198  |
# |    ent_coef        | 0.0635    |
# |    ent_coef_loss   | -0.32     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 62047     |
# ----------------------------------
# INFO: SAC Model learn finished
# INFO: Evaluating Session: datasets/1-Open Data/m80/-10C/Drive Cycles/9_CC_CV_charge_11-06-21_01.59 Tesla_n10C_DriveCycles_Ch1.mat ---
# MAE   : 0.03480
# RMSE  : 0.03521
# MAPE  : 4.53%
# R2    : 0.97994
# {'mae': np.float64(0.034803979199310144),
#  'rmse': np.float64(0.03520737571664342),
#  'mape': np.float64(4.5325766853466485),
#  'r2': 0.9799420445597962}

# %% [markdown]
# # Proximal Policy Optimization

# %%
PPO_model = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0003)

print("Memulai Training...")
PPO_model.learn(total_timesteps=100000)
PPO_model.save("ppo_soc_battery")

evaluate_model(PPO_model, df_test)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Memulai Training...
# -----------------------------
# | time/              |      |
# |    fps             | 578  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.025691135 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00185    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.404       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.93        |
# |    value_loss           | 4.38        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.021504346 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -5.04e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.253       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.877       |
# |    value_loss           | 2.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013102084 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0616      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.434       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.839       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0066065965 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0949       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.84         |
# |    value_loss           | 14.5         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1049       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01718938 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.0103     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.34       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0195    |
# |    std                  | 0.84       |
# |    value_loss           | 30.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017576648 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -6.78e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.843       |
# |    value_loss           | 20.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1090       |
# |    iterations           | 8          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02009052 |
# |    clip_fraction        | 0.276      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | -2.84e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.53       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0355    |
# |    std                  | 0.846      |
# |    value_loss           | 9.61       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1106       |
# |    iterations           | 9          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02317619 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | -5.48e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.514      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0381    |
# |    std                  | 0.832      |
# |    value_loss           | 2.83       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 10          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.022952773 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 2.32e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.535       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0392     |
# |    std                  | 0.787       |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.024199238 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.4         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0424     |
# |    std                  | 0.746       |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 12          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009795854 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.023      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.198       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00664    |
# |    std                  | 0.722       |
# |    value_loss           | 7.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1039        |
# |    iterations           | 13          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.024000762 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 4.01e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.165       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.641       |
# |    value_loss           | 0.425       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1051        |
# |    iterations           | 14          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009164037 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 1.91e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.591       |
# |    value_loss           | 0.398       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009631444 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 1.7e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0833      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.539       |
# |    value_loss           | 0.326       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.07e+04     |
# |    ep_rew_mean          | -9.96e+03    |
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0059180623 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | -2.81e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0676       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.502        |
# |    value_loss           | 0.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.07e+04     |
# |    ep_rew_mean          | -9.96e+03    |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0069170175 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -6.02e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0499       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0077      |
# |    std                  | 0.464        |
# |    value_loss           | 0.291        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 18          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008179209 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 8.35e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00888    |
# |    std                  | 0.429       |
# |    value_loss           | 0.346       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1096        |
# |    iterations           | 19          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011021113 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.000661    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0497      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.392       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 20          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006200661 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.38        |
# |    value_loss           | 0.284       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1108        |
# |    iterations           | 21          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019386502 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 0.000326    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.181       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.362       |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 22          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017406888 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | -0.00111    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.264       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.347       |
# |    value_loss           | 0.623       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 23          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015945649 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.00107     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.198       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.333       |
# |    value_loss           | 0.615       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.07e+04  |
# |    ep_rew_mean          | -9.96e+03 |
# | time/                   |           |
# |    fps                  | 1125      |
# |    iterations           | 24        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0179385 |
# |    clip_fraction        | 0.231     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.296    |
# |    explained_variance   | 0.000419  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.222     |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0339   |
# |    std                  | 0.317     |
# |    value_loss           | 0.674     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+04    |
# |    ep_rew_mean          | -9.96e+03   |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 25          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.020969551 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.245      |
# |    explained_variance   | -5.11e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.235       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0329     |
# |    std                  | 0.301       |
# |    value_loss           | 0.548       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65e+04    |
# |    ep_rew_mean          | -9.09e+03   |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 26          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018211842 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.197      |
# |    explained_variance   | 0.000308    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0902      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.288       |
# |    value_loss           | 0.575       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.65e+04     |
# |    ep_rew_mean          | -9.09e+03    |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 27           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0070807207 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.16        |
# |    explained_variance   | -0.000496    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.931        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00834     |
# |    std                  | 0.281        |
# |    value_loss           | 2.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65e+04    |
# |    ep_rew_mean          | -9.09e+03   |
# | time/                   |             |
# |    fps                  | 1091        |
# |    iterations           | 28          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008472372 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | -1.97       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0362      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00684    |
# |    std                  | 0.27        |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65e+04    |
# |    ep_rew_mean          | -9.09e+03   |
# | time/                   |             |
# |    fps                  | 1096        |
# |    iterations           | 29          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013441812 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0579     |
# |    explained_variance   | 0.0397      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.052       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.247       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.65e+04   |
# |    ep_rew_mean          | -9.09e+03  |
# | time/                   |            |
# |    fps                  | 1100       |
# |    iterations           | 30         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02003831 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.028      |
# |    explained_variance   | 0.161      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0806     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 0.226      |
# |    value_loss           | 0.164      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65e+04    |
# |    ep_rew_mean          | -9.09e+03   |
# | time/                   |             |
# |    fps                  | 1103        |
# |    iterations           | 31          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.019354623 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0909      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 0.216       |
# |    value_loss           | 0.0981      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 32           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0057792496 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.117        |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0403       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.215        |
# |    value_loss           | 0.135        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+04    |
# |    ep_rew_mean          | -6.68e+03   |
# | time/                   |             |
# |    fps                  | 1066        |
# |    iterations           | 33          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.013970067 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.123       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00497    |
# |    std                  | 0.212       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 34           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0107213035 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.146        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0242       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 0.206        |
# |    value_loss           | 0.23         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 35           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0091247335 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.175        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00579      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.2          |
# |    value_loss           | 0.154        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1079         |
# |    iterations           | 36           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0049593123 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.209        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00409     |
# |    std                  | 0.193        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+04    |
# |    ep_rew_mean          | -6.68e+03   |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 37          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008062137 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.237       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00418    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00729    |
# |    std                  | 0.19        |
# |    value_loss           | 0.0722      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1087         |
# |    iterations           | 38           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0065974933 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.247        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0108       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0071      |
# |    std                  | 0.189        |
# |    value_loss           | 0.0503       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1091         |
# |    iterations           | 39           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0063573555 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.268        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00569      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00452     |
# |    std                  | 0.182        |
# |    value_loss           | 0.0366       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+04    |
# |    ep_rew_mean          | -6.68e+03   |
# | time/                   |             |
# |    fps                  | 1092        |
# |    iterations           | 40          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004481206 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.296       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.023       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00204    |
# |    std                  | 0.178       |
# |    value_loss           | 0.0222      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1096         |
# |    iterations           | 41           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0075075775 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.318        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00859     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00548     |
# |    std                  | 0.174        |
# |    value_loss           | 0.0146       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+04     |
# |    ep_rew_mean          | -6.68e+03    |
# | time/                   |              |
# |    fps                  | 1098         |
# |    iterations           | 42           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0068168216 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.339        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00222     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00276     |
# |    std                  | 0.171        |
# |    value_loss           | 0.0102       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+04    |
# |    ep_rew_mean          | -6.68e+03   |
# | time/                   |             |
# |    fps                  | 1101        |
# |    iterations           | 43          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006873032 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.359       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00165    |
# |    std                  | 0.167       |
# |    value_loss           | 0.00898     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+04    |
# |    ep_rew_mean          | -5.05e+03   |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 44          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004882064 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.379       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00629     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00133    |
# |    std                  | 0.165       |
# |    value_loss           | 0.00846     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+04    |
# |    ep_rew_mean          | -5.05e+03   |
# | time/                   |             |
# |    fps                  | 1075        |
# |    iterations           | 45          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010409431 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.392       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0227      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.162       |
# |    value_loss           | 0.024       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+04    |
# |    ep_rew_mean          | -5.05e+03   |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 46          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.016412513 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.402       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0265      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00332     |
# |    std                  | 0.161       |
# |    value_loss           | 0.0223      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+04    |
# |    ep_rew_mean          | -5.05e+03   |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 47          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013609782 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.408       |
# |    explained_variance   | -0.924      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00417    |
# |    std                  | 0.161       |
# |    value_loss           | 0.48        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.24e+04     |
# |    ep_rew_mean          | -5.05e+03    |
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 48           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0024319363 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.405        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00236     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00163      |
# |    std                  | 0.162        |
# |    value_loss           | 0.0905       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+04    |
# |    ep_rew_mean          | -5.05e+03   |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 49          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004837025 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.416       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00227    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.000772    |
# |    std                  | 0.158       |
# |    value_loss           | 0.0215      |
# -----------------------------------------
# INFO: Evaluating Session: datasets/1-Open Data/m80/10C/Characterization Tests/5_CC_CV_charge_09-10-21_19.37 Tesla_Cher_10C_Channel_1_Wb_1.mat ---
# MAE   : 0.06123
# RMSE  : 0.09700
# MAPE  : 35.99%
# R2    : 0.94420
# {'mae': np.float64(0.06123247532873425),
#  'rmse': np.float64(0.09700042341781592),
#  'mape': np.float64(35.98593130642366),
#  'r2': 0.9441970959581457}

# %% [markdown]
# # Trust Region Proximal Optimization

# %%
TRPO_model = TRPO("MlpPolicy", env, verbose=1, learning_rate=0.0003)

print("Memulai Training...")
TRPO_model.learn(total_timesteps=100000)
TRPO_model.save("trpo_soc_battery")

evaluate_model(TRPO_model, df_test)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Memulai Training...
# -----------------------------
# | time/              |      |
# |    fps             | 613  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 902       |
# |    iterations             | 2         |
# |    time_elapsed           | 4         |
# |    total_timesteps        | 4096      |
# | train/                    |           |
# |    explained_variance     | -0.000159 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00986   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 1         |
# |    policy_objective       | 0.0351    |
# |    std                    | 1.04      |
# |    value_loss             | 69.5      |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1066     |
# |    iterations             | 3        |
# |    time_elapsed           | 5        |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.0114   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00987  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 2        |
# |    policy_objective       | 0.0366   |
# |    std                    | 1.07     |
# |    value_loss             | 41       |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1176     |
# |    iterations             | 4        |
# |    time_elapsed           | 6        |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 1.21e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00991  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 3        |
# |    policy_objective       | 0.0412   |
# |    std                    | 1.09     |
# |    value_loss             | 31.9     |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1251     |
# |    iterations             | 5        |
# |    time_elapsed           | 8        |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.0003   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00995  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 4        |
# |    policy_objective       | 0.0386   |
# |    std                    | 1.08     |
# |    value_loss             | 21.1     |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1308     |
# |    iterations             | 6        |
# |    time_elapsed           | 9        |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | -0.00214 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00998  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 5        |
# |    policy_objective       | 0.0411   |
# |    std                    | 1.07     |
# |    value_loss             | 12.9     |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1349     |
# |    iterations             | 7        |
# |    time_elapsed           | 10       |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | -0.00103 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00999  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 6        |
# |    policy_objective       | 0.0397   |
# |    std                    | 1.06     |
# |    value_loss             | 6.99     |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1383     |
# |    iterations             | 8        |
# |    time_elapsed           | 11       |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 2.38e-07 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00993  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 7        |
# |    policy_objective       | 0.0401   |
# |    std                    | 1.02     |
# |    value_loss             | 3.39     |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1410      |
# |    iterations             | 9         |
# |    time_elapsed           | 13        |
# |    total_timesteps        | 18432     |
# | train/                    |           |
# |    explained_variance     | -4.63e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0064    |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 8         |
# |    policy_objective       | 0.0335    |
# |    std                    | 0.999     |
# |    value_loss             | 2.13      |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1426      |
# |    iterations             | 10        |
# |    time_elapsed           | 14        |
# |    total_timesteps        | 20480     |
# | train/                    |           |
# |    explained_variance     | -0.000322 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00985   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 9         |
# |    policy_objective       | 0.0403    |
# |    std                    | 0.952     |
# |    value_loss             | 1.13      |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1442      |
# |    iterations             | 11        |
# |    time_elapsed           | 15        |
# |    total_timesteps        | 22528     |
# | train/                    |           |
# |    explained_variance     | -3.66e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00971   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 10        |
# |    policy_objective       | 0.0391    |
# |    std                    | 0.896     |
# |    value_loss             | 0.497     |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1445      |
# |    iterations             | 12        |
# |    time_elapsed           | 17        |
# |    total_timesteps        | 24576     |
# | train/                    |           |
# |    explained_variance     | -0.000284 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00978   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 11        |
# |    policy_objective       | 0.0365    |
# |    std                    | 0.848     |
# |    value_loss             | 0.301     |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1459     |
# |    iterations             | 13       |
# |    time_elapsed           | 18       |
# |    total_timesteps        | 26624    |
# | train/                    |          |
# |    explained_variance     | 0.0028   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00946  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 12       |
# |    policy_objective       | 0.0348   |
# |    std                    | 0.787    |
# |    value_loss             | 0.271    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1468     |
# |    iterations             | 14       |
# |    time_elapsed           | 19       |
# |    total_timesteps        | 28672    |
# | train/                    |          |
# |    explained_variance     | -0.00359 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00953  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 13       |
# |    policy_objective       | 0.0218   |
# |    std                    | 0.733    |
# |    value_loss             | 0.307    |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1476      |
# |    iterations             | 15        |
# |    time_elapsed           | 20        |
# |    total_timesteps        | 30720     |
# | train/                    |           |
# |    explained_variance     | -4.03e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00894   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 14        |
# |    policy_objective       | 0.0167    |
# |    std                    | 0.665     |
# |    value_loss             | 0.146     |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1482      |
# |    iterations             | 16        |
# |    time_elapsed           | 22        |
# |    total_timesteps        | 32768     |
# | train/                    |           |
# |    explained_variance     | -0.000943 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00973   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 15        |
# |    policy_objective       | 0.0104    |
# |    std                    | 0.636     |
# |    value_loss             | 0.0974    |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1487     |
# |    iterations             | 17       |
# |    time_elapsed           | 23       |
# |    total_timesteps        | 34816    |
# | train/                    |          |
# |    explained_variance     | -0.0126  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0088   |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 16       |
# |    policy_objective       | 0.0125   |
# |    std                    | 0.579    |
# |    value_loss             | 0.0882   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1496     |
# |    iterations             | 18       |
# |    time_elapsed           | 24       |
# |    total_timesteps        | 36864    |
# | train/                    |          |
# |    explained_variance     | 0.0037   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00638  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 17       |
# |    policy_objective       | 0.00918  |
# |    std                    | 0.604    |
# |    value_loss             | 0.589    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1500     |
# |    iterations             | 19       |
# |    time_elapsed           | 25       |
# |    total_timesteps        | 38912    |
# | train/                    |          |
# |    explained_variance     | 4.05e-06 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00985  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 18       |
# |    policy_objective       | 0.0229   |
# |    std                    | 0.612    |
# |    value_loss             | 0.452    |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1505      |
# |    iterations             | 20        |
# |    time_elapsed           | 27        |
# |    total_timesteps        | 40960     |
# | train/                    |           |
# |    explained_variance     | -0.000136 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00985   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 19        |
# |    policy_objective       | 0.0206    |
# |    std                    | 0.62      |
# |    value_loss             | 0.32      |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1511     |
# |    iterations             | 21       |
# |    time_elapsed           | 28       |
# |    total_timesteps        | 43008    |
# | train/                    |          |
# |    explained_variance     | -0.00659 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00964  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 20       |
# |    policy_objective       | 0.0202   |
# |    std                    | 0.584    |
# |    value_loss             | 0.264    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1515     |
# |    iterations             | 22       |
# |    time_elapsed           | 29       |
# |    total_timesteps        | 45056    |
# | train/                    |          |
# |    explained_variance     | 0.00421  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00648  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 21       |
# |    policy_objective       | 0.0113   |
# |    std                    | 0.58     |
# |    value_loss             | 0.691    |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1520      |
# |    iterations             | 23        |
# |    time_elapsed           | 30        |
# |    total_timesteps        | 47104     |
# | train/                    |           |
# |    explained_variance     | -4.53e-06 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00982   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 22        |
# |    policy_objective       | 0.0256    |
# |    std                    | 0.56      |
# |    value_loss             | 0.488     |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1524     |
# |    iterations             | 24       |
# |    time_elapsed           | 32       |
# |    total_timesteps        | 49152    |
# | train/                    |          |
# |    explained_variance     | -0.00173 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00973  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 23       |
# |    policy_objective       | 0.0278   |
# |    std                    | 0.537    |
# |    value_loss             | 0.304    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1527     |
# |    iterations             | 25       |
# |    time_elapsed           | 33       |
# |    total_timesteps        | 51200    |
# | train/                    |          |
# |    explained_variance     | 0.000312 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0096   |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 24       |
# |    policy_objective       | 0.0231   |
# |    std                    | 0.505    |
# |    value_loss             | 0.319    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1528     |
# |    iterations             | 26       |
# |    time_elapsed           | 34       |
# |    total_timesteps        | 53248    |
# | train/                    |          |
# |    explained_variance     | 0.000245 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00978  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 25       |
# |    policy_objective       | 0.0368   |
# |    std                    | 0.482    |
# |    value_loss             | 0.37     |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1532     |
# |    iterations             | 27       |
# |    time_elapsed           | 36       |
# |    total_timesteps        | 55296    |
# | train/                    |          |
# |    explained_variance     | 3.58e-07 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00975  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 26       |
# |    policy_objective       | 0.0339   |
# |    std                    | 0.459    |
# |    value_loss             | 0.333    |
# ----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1535      |
# |    iterations             | 28        |
# |    time_elapsed           | 37        |
# |    total_timesteps        | 57344     |
# | train/                    |           |
# |    explained_variance     | -0.000849 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00964   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 27        |
# |    policy_objective       | 0.0346    |
# |    std                    | 0.432     |
# |    value_loss             | 0.301     |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1538      |
# |    iterations             | 29        |
# |    time_elapsed           | 38        |
# |    total_timesteps        | 59392     |
# | train/                    |           |
# |    explained_variance     | -0.000749 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00966   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 28        |
# |    policy_objective       | 0.0333    |
# |    std                    | 0.405     |
# |    value_loss             | 0.376     |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1542      |
# |    iterations             | 30        |
# |    time_elapsed           | 39        |
# |    total_timesteps        | 61440     |
# | train/                    |           |
# |    explained_variance     | -8.93e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00957   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 29        |
# |    policy_objective       | 0.0371    |
# |    std                    | 0.378     |
# |    value_loss             | 0.394     |
# -----------------------------------------
# -----------------------------------------
# | time/                     |           |
# |    fps                    | 1545      |
# |    iterations             | 31        |
# |    time_elapsed           | 41        |
# |    total_timesteps        | 63488     |
# | train/                    |           |
# |    explained_variance     | -9.35e-05 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00937   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 30        |
# |    policy_objective       | 0.0372    |
# |    std                    | 0.35      |
# |    value_loss             | 0.351     |
# -----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1548     |
# |    iterations             | 32       |
# |    time_elapsed           | 42       |
# |    total_timesteps        | 65536    |
# | train/                    |          |
# |    explained_variance     | 0.000172 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00924  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 31       |
# |    policy_objective       | 0.0378   |
# |    std                    | 0.321    |
# |    value_loss             | 0.423    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1551     |
# |    iterations             | 33       |
# |    time_elapsed           | 43       |
# |    total_timesteps        | 67584    |
# | train/                    |          |
# |    explained_variance     | 0.000411 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00927  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 32       |
# |    policy_objective       | 0.0393   |
# |    std                    | 0.295    |
# |    value_loss             | 0.478    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1554     |
# |    iterations             | 34       |
# |    time_elapsed           | 44       |
# |    total_timesteps        | 69632    |
# | train/                    |          |
# |    explained_variance     | 3.06e-05 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00947  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 33       |
# |    policy_objective       | 0.0367   |
# |    std                    | 0.274    |
# |    value_loss             | 0.477    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1556     |
# |    iterations             | 35       |
# |    time_elapsed           | 46       |
# |    total_timesteps        | 71680    |
# | train/                    |          |
# |    explained_variance     | 0.0011   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00923  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 34       |
# |    policy_objective       | 0.0329   |
# |    std                    | 0.252    |
# |    value_loss             | 0.439    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1558     |
# |    iterations             | 36       |
# |    time_elapsed           | 47       |
# |    total_timesteps        | 73728    |
# | train/                    |          |
# |    explained_variance     | -0.0346  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00893  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 35       |
# |    policy_objective       | 0.0358   |
# |    std                    | 0.23     |
# |    value_loss             | 0.299    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1561     |
# |    iterations             | 37       |
# |    time_elapsed           | 48       |
# |    total_timesteps        | 75776    |
# | train/                    |          |
# |    explained_variance     | 0.0188   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00904  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 36       |
# |    policy_objective       | 0.0329   |
# |    std                    | 0.21     |
# |    value_loss             | 0.213    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1563     |
# |    iterations             | 38       |
# |    time_elapsed           | 49       |
# |    total_timesteps        | 77824    |
# | train/                    |          |
# |    explained_variance     | 0.000485 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00899  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 37       |
# |    policy_objective       | 0.0237   |
# |    std                    | 0.191    |
# |    value_loss             | 0.169    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1564     |
# |    iterations             | 39       |
# |    time_elapsed           | 51       |
# |    total_timesteps        | 79872    |
# | train/                    |          |
# |    explained_variance     | -0.142   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.009    |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 38       |
# |    policy_objective       | 0.0251   |
# |    std                    | 0.174    |
# |    value_loss             | 0.142    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1565     |
# |    iterations             | 40       |
# |    time_elapsed           | 52       |
# |    total_timesteps        | 81920    |
# | train/                    |          |
# |    explained_variance     | 0.487    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00802  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 39       |
# |    policy_objective       | 0.0283   |
# |    std                    | 0.163    |
# |    value_loss             | 0.139    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1566     |
# |    iterations             | 41       |
# |    time_elapsed           | 53       |
# |    total_timesteps        | 83968    |
# | train/                    |          |
# |    explained_variance     | 0.00499  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00898  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 40       |
# |    policy_objective       | 0.0205   |
# |    std                    | 0.148    |
# |    value_loss             | 0.0993   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1566     |
# |    iterations             | 42       |
# |    time_elapsed           | 54       |
# |    total_timesteps        | 86016    |
# | train/                    |          |
# |    explained_variance     | 0.00437  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00899  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 41       |
# |    policy_objective       | 0.0225   |
# |    std                    | 0.136    |
# |    value_loss             | 0.0818   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1567     |
# |    iterations             | 43       |
# |    time_elapsed           | 56       |
# |    total_timesteps        | 88064    |
# | train/                    |          |
# |    explained_variance     | -0.466   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00843  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 42       |
# |    policy_objective       | 0.0156   |
# |    std                    | 0.128    |
# |    value_loss             | 0.0888   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1568     |
# |    iterations             | 44       |
# |    time_elapsed           | 57       |
# |    total_timesteps        | 90112    |
# | train/                    |          |
# |    explained_variance     | 0.616    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00914  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 43       |
# |    policy_objective       | 0.0151   |
# |    std                    | 0.119    |
# |    value_loss             | 0.0676   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1569     |
# |    iterations             | 45       |
# |    time_elapsed           | 58       |
# |    total_timesteps        | 92160    |
# | train/                    |          |
# |    explained_variance     | 0.00663  |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00904  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 44       |
# |    policy_objective       | 0.0193   |
# |    std                    | 0.108    |
# |    value_loss             | 0.0546   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1569     |
# |    iterations             | 46       |
# |    time_elapsed           | 60       |
# |    total_timesteps        | 94208    |
# | train/                    |          |
# |    explained_variance     | -0.634   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00738  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 45       |
# |    policy_objective       | 0.00475  |
# |    std                    | 0.103    |
# |    value_loss             | 0.0492   |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1570     |
# |    iterations             | 47       |
# |    time_elapsed           | 61       |
# |    total_timesteps        | 96256    |
# | train/                    |          |
# |    explained_variance     | 0.849    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00912  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 46       |
# |    policy_objective       | 0.0281   |
# |    std                    | 0.097    |
# |    value_loss             | 0.073    |
# ----------------------------------------
# ----------------------------------------
# | time/                     |          |
# |    fps                    | 1570     |
# |    iterations             | 48       |
# |    time_elapsed           | 62       |
# |    total_timesteps        | 98304    |
# | train/                    |          |
# |    explained_variance     | 0.0281   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00966  |
# |    learning_rate          | 0.0003   |
# |    n_updates              | 47       |
# |    policy_objective       | 0.0263   |
# |    std                    | 0.0914   |
# |    value_loss             | 0.0487   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 1e+05     |
# |    ep_rew_mean            | -2.65e+04 |
# | time/                     |           |
# |    fps                    | 1513      |
# |    iterations             | 49        |
# |    time_elapsed           | 66        |
# |    total_timesteps        | 100352    |
# | train/                    |           |
# |    explained_variance     | -0.267    |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00862   |
# |    learning_rate          | 0.0003    |
# |    n_updates              | 48        |
# |    policy_objective       | 0.0242    |
# |    std                    | 0.0863    |
# |    value_loss             | 0.0405    |
# -----------------------------------------
# INFO: Evaluating Session: datasets/1-Open Data/m80/25C/Drive Cycles/12_REORDERED2_06-07-21_08.52 Tesla_25C_DriveCycles_Ch1.mat ---
# MAE   : 0.60774
# RMSE  : 0.60774
# MAPE  : 60.77%
# R2    : 0.00000
# {'mae': np.float64(0.6077402234077454),
#  'rmse': np.float64(0.6077402234077454),
#  'mape': np.float64(60.77402233469711),
#  'r2': 0.0}
